# %%
from langchain_core.language_models.fake_chat_models import FakeChatModel
from langchain_core.prompts import PromptTemplate
import pprint as pp

from src.parsers import StateConnector
from src.wrappers import SmartPromptVariable, PromptWrapper

# %%
state = {
  "movies": [
    {
      "title": "Inception",
      "description": "A skilled thief leads a team into people's dreams to steal secrets.",
      "status": "active",
      "release_date": "2010-07-16",
      "budget": 160000000,
      "box_office": 829895144,
      "rating": 4.8,
      "tags": ["action", "sci-fi", "thriller"],
      "reviews": [
        {
          "user": "Alice123",
          "rating": 5,
          "comment": "Mind-blowing visuals and an intricate plot that rewards attentive viewers. The dream-within-a-dream concept was brilliantly executed, and Hans Zimmer's score perfectly complemented the tension. Leonardo DiCaprio delivers a compelling performance, making the emotional stakes feel genuine."
        },
        {
          "user": "MovieBuff89",
          "rating": 4.5,
          "comment": "An innovative concept brought to life with stellar direction and stunning special effects. The seamless blending of multiple dream layers kept me engaged throughout the entire film. However, some parts felt a bit too convoluted, requiring multiple viewings to fully grasp."
        },
        {
          "user": "CriticTom",
          "rating": 4,
          "comment": "Excellent execution with a thought-provoking storyline. The ensemble cast works exceptionally well together, and the action sequences are both thrilling and visually impressive. That said, the complex narrative might be overwhelming for some viewers."
        }
      ]
    },
    {
      "title": "Avengers: Endgame",
      "description": "The Avengers assemble for a final battle to save the universe from Thanos.",
      "status": "active",
      "release_date": "2019-04-26",
      "budget": 356000000,
      "box_office": 2797501328,
      "rating": 4.9,
      "tags": ["action", "superhero", "sci-fi"],
      "reviews": [
        {
          "user": "MarvelManiac",
          "rating": 5,
          "comment": "An epic conclusion that delivers emotional depth and breathtaking action. The way the film wraps up over a decade of storytelling is nothing short of genius. Each character gets their moment to shine, and the final battle scene is one of the most exhilarating I've ever seen."
        },
        {
          "user": "BlockbusterBuff",
          "rating": 4.8,
          "comment": "Unforgettable and grand in scale, though slightly long. The emotional moments between characters are heartfelt, and the visual effects are top-notch. Some plot points felt rushed towards the end, but overall, it's a triumphant finish to the Avengers saga."
        },
        {
          "user": "ComicLover",
          "rating": 4.9,
          "comment": "A perfect payoff for over a decade of storytelling. The character arcs are beautifully resolved, and the stakes have never felt higher. Robert Downey Jr. and Chris Evans deliver standout performances, making the sacrifices they make truly impactful."
        }
      ]
    },
    {
      "title": "The Godfather",
      "description": "An organized crime dynasty's aging patriarch transfers control of his empire to his reluctant son.",
      "status": "active",
      "release_date": "1972-03-24",
      "budget": 6000000,
      "box_office": 245066411,
      "rating": 4.9,
      "tags": ["crime", "drama", "classic"],
      "reviews": [
        {
          "user": "ClassicCarl",
          "rating": 5,
          "comment": "Flawless acting and storytelling. Marlon Brando's portrayal of Vito Corleone is legendary, and Al Pacino's transformation throughout the film is mesmerizing. The film's pacing and dialogue are masterfully crafted, making it a timeless classic."
        },
        {
          "user": "VinnyV",
          "rating": 4.8,
          "comment": "Gripping drama and memorable characters. The intricate plot delves deep into the complexities of power, family, and loyalty. The cinematography and music add to the film's immersive atmosphere, making it an essential watch for any movie enthusiast."
        },
        {
          "user": "OldSchoolOscar",
          "rating": 5,
          "comment": "A true masterpiece that transcends its genre. The Godfather's influence on cinema is undeniable, setting the standard for gangster films. Every scene is meticulously crafted, and the performances are nothing short of extraordinary."
        }
      ]
    },
    {
      "title": "Battlefield Earth",
      "description": "In a dystopian future, humanity fights back against alien oppressors.",
      "status": "canceled",
      "release_date": "2000-05-12",
      "budget": 73000000,
      "box_office": 29700000,
      "rating": 1.2,
      "tags": ["sci-fi", "action", "drama"],
      "reviews": [
        {
          "user": "AlienHater",
          "rating": 1,
          "comment": "A painfully bad script, laughable acting, and unwatchable direction. The plot is nonsensical, and the special effects feel outdated and poorly executed. It's hard to find any redeeming qualities in this disaster of a film."
        },
        {
          "user": "SciFiCritic",
          "rating": 1.5,
          "comment": "The premise had potential, but everything else was a disaster. The character development is nonexistent, and the pacing drags on unnecessarily. It's one of the worst adaptations I've ever seen."
        },
        {
          "user": "FutureFan",
          "rating": 1,
          "comment": "One of the worst movies I've ever seen. Avoid at all costs. The storyline is incoherent, and the performances are subpar, making it nearly impossible to stay engaged."
        }
      ]
    },
    {
      "title": "John Carter",
      "description": "A Civil War soldier is transported to Mars, where he becomes embroiled in a conflict among its inhabitants.",
      "status": "active",
      "release_date": "2012-03-09",
      "budget": 263000000,
      "box_office": 284139100,
      "rating": 2.7,
      "tags": ["action", "adventure", "sci-fi"],
      "reviews": [
        {
          "user": "SpaceFanatic",
          "rating": 2,
          "comment": "Despite the massive budget, the film lacked focus and a compelling narrative. The world-building was impressive, but the character motivations were unclear, making it hard to invest in the story."
        },
        {
          "user": "AdventureAddict",
          "rating": 3,
          "comment": "Some exciting moments and impressive visuals, but overall a bloated and confusing storyline. The pacing was uneven, and certain plot points felt rushed or underdeveloped."
        },
        {
          "user": "MovieMaven",
          "rating": 2.5,
          "comment": "A visual spectacle that lacked depth and engaging characters. The performances were adequate, but the film failed to capture the magic of the source material, leaving viewers feeling disconnected."
        }
      ]
    },
    {
      "title": "Cutthroat Island",
      "description": "A female pirate and her companion race against rivals to find a hidden treasure.",
      "status": "canceled",
      "release_date": "1995-12-22",
      "budget": 9800000000,
      "box_office": 10017322,
      "rating": 2.0,
      "tags": ["adventure", "action", "period"],
      "reviews": [
        {
          "user": "PiratePaul",
          "rating": 2,
          "comment": "Huge budget squandered on weak storytelling and dull characters. The action scenes felt repetitive, and the romantic subplot was unconvincing."
        },
        {
          "user": "TreasureTina",
          "rating": 1.5,
          "comment": "A tedious pirate adventure with no real thrills or charm. The dialogue was clichéd, and the plot was predictable from start to finish."
        },
        {
          "user": "MovieMariner",
          "rating": 2,
          "comment": "Expensive, but fails to deliver excitement or engaging drama. The performances lacked depth, and the film struggled to maintain any sense of momentum."
        }
      ]
    },
    {
      "title": "Jungle Cruise",
      "description": "A charismatic riverboat captain takes a scientist and her brother on a mission into the Amazon.",
      "status": "active",
      "release_date": "2021-07-30",
      "budget": 200000000,
      "box_office": 221900000,
      "rating": 3.5,
      "tags": ["adventure", "fantasy", "action"],
      "reviews": [
        {
          "user": "AdventureAlice",
          "rating": 3,
          "comment": "Entertaining ride with decent action sequences and a charming cast. However, the plot is somewhat predictable and lacks originality, making it feel like a standard adventure film."
        },
        {
          "user": "FantasyFrank",
          "rating": 3.5,
          "comment": "Good chemistry between Dwayne Johnson and Emily Blunt, which adds some fun to the movie. The special effects are impressive, but the story doesn't take many risks, resulting in a familiar narrative."
        },
        {
          "user": "CasualCindy",
          "rating": 3,
          "comment": "A fun weekend watch with enjoyable performances, but it doesn't leave a lasting impression. The blend of humor and action works well, but the film could benefit from a more engaging storyline."
        }
      ]
    },
    {
      "title": "The Meg",
      "description": "A rescue diver encounters a massive prehistoric shark while searching for a sunken sub.",
      "status": "active",
      "release_date": "2018-08-10",
      "budget": 130000000,
      "box_office": 530000000,
      "rating": 3.2,
      "tags": ["action", "thriller", "sci-fi"],
      "reviews": [
        {
          "user": "SharkLover",
          "rating": 3.5,
          "comment": "Exciting shark action and entertaining premise. The Meg offers plenty of thrilling moments, especially during the underwater sequences. However, the storyline is pretty standard and doesn't offer much beyond the action."
        },
        {
          "user": "ActionAndy",
          "rating": 3,
          "comment": "Good special effects and some intense chase scenes, but the character development is lacking. The film prioritizes spectacle over substance, which makes it enjoyable but not particularly memorable."
        },
        {
          "user": "CasualChris",
          "rating": 3,
          "comment": "A fun, if not very original, underwater adventure. While the concept is engaging, the execution falls into familiar tropes, making the movie feel like a typical creature feature."
        }
      ]
    },
    {
      "title": "Speed Racer",
      "description": "A young race car driver aims to honor his family and unmask corruption in the racing world.",
      "status": "active",
      "release_date": "2008-05-09",
      "budget": 100000000,
      "box_office": 141123068,
      "rating": 2.9,
      "tags": ["action", "sports", "family"],
      "reviews": [
        {
          "user": "RacerRick",
          "rating": 3,
          "comment": "Fun racing sequences with innovative visual styles, but the excessive CGI is distracting. The film tries to push boundaries but ends up feeling chaotic at times."
        },
        {
          "user": "ActionAndy",
          "rating": 2.5,
          "comment": "Visually striking and filled with energy, but the story is hard to follow and lacks emotional depth. The unique aesthetic is a double-edged sword, making it both memorable and overwhelming."
        },
        {
          "user": "MovieMike",
          "rating": 3,
          "comment": "Decent entertainment value with plenty of action, but nothing groundbreaking. The performances are solid, but the plot feels secondary to the visual spectacle."
        }
      ]
    }
  ]
}

# %%
# Wrapping entire prompt into a wrapper

model = FakeChatModel()

template = """
You are a data investigator and you need to find out why some movies flopped.

Here is the list of flopped movies with their meta-data: 

{SELECT title, rating FROM state.movies WHERE movies.budget > 10000}
"""

connector = StateConnector(object_map = {'state': state})
prompt = PromptTemplate(template=template)
wrapped_prompt = PromptWrapper(prompt)
pp.pprint(wrapped_prompt.prompt.format(**wrapped_prompt.values))
# Out:
# ('\n'
#  'You are a data investigator and you need to find out why some movies '
#  'flopped.\n'
#  '\n'
#  'Here is the list of flopped movies with their meta-data: \n'
#  '\n'
#  "[{'title': 'Inception', 'rating': 4.8}, {'title': 'Avengers: Endgame', "
#  "'rating': 4.9}, {'title': 'The Godfather', 'rating': 4.9}, {'title': "
#  "'Battlefield Earth', 'rating': 1.2}, {'title': 'John Carter', 'rating': "
#  "2.7}, {'title': 'Cutthroat Island', 'rating': 2.0}, {'title': 'Jungle "
#  "Cruise', 'rating': 3.5}, {'title': 'The Meg', 'rating': 3.2}, {'title': "
#  "'Speed Racer', 'rating': 2.9}]\n")
